# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create list of cities

## Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

## Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

## Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

## Create a list for holding the cities.
cities = []

## Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    ## If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
## Print the city count to confirm sufficient count.
len(cities)
# Out:
# 722

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4aaf526f731ea82acff5774904596bb5

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)

# Get the text of the 'Get' request to see the keys to be used in next step. 
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 64.47,
#   'feels_like': 62.82,
#   'temp_min': 62.01,
#   'temp_max': 66.2,
#   'pressure': 1014,
#   'humidity': 72},
#  'visibility': 10000,
#  'wind': {'speed': 5.82, 'deg': 20},
#  'clouds': {'all': 75},
#  'dt': 1597882801,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1597830979,
#   'sunset': 1597880370},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description, 
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | mahebourg
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | constitucion
# Processing Record 9 of Set 1 | ulladulla
# Processing Record 10 of Set 1 | iskateley
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | aklavik
# Processing Record 14 of Set 1 | airai
# Processing Record 15 of Set 1 | bababe
# City not found. Skipping...
# Processing Record 16 of Set 1 | yumen
# Processing Record 17 of Set 1 | severo-kurilsk
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | nuuk
# Processing Record 21 of Set 1 | arcata
# Processing Record 22 of Set 1 | port blair
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | vilyuysk
# Processing Record 25 of Set 1 | guerrero negro
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | nantucket
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | myitkyina
# Processing Record 30 of Set 1 | dikson
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | itarema
# Processing Record 33 of Set 1 | port moresby
# Processing Record 34 of Set 1 | tiksi
# Processing Record 35 of Set 1 | taltal
# Processing Record 36 of Set 1 | panguna
# Processing Record 37 of Set 1 | lynn haven
# Processing Record 38 of Set 1 | talcahuano
# Processing Record 39 of Set 1 | belize
# Processing Record 40 of Set 1 | kesennuma
# City not found. Skipping...
# Processing Record 41 of Set 1 | dingle
# Processing Record 42 of Set 1 | the valley
# Processing Record 43 of Set 1 | kieta
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | kericho
# Processing Record 47 of Set 1 | coquimbo
# Processing Record 48 of Set 1 | changli
# Processing Record 49 of Set 1 | galiwinku
# City not found. Skipping...
# Processing Record 50 of Set 1 | dzheyrakh
# Processing Record 1 of Set 2 | mercedes
# Processing Record 2 of Set 2 | malanje
# Processing Record 3 of Set 2 | xingyi
# Processing Record 4 of Set 2 | cherskiy
# Processing Record 5 of Set 2 | cockburn town
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | torbay
# Processing Record 8 of Set 2 | ponta do sol
# Processing Record 9 of Set 2 | khandyga
# Processing Record 10 of Set 2 | divnomorskoye
# Processing Record 11 of Set 2 | aketi
# Processing Record 12 of Set 2 | vardo
# Processing Record 13 of Set 2 | hasaki
# Processing Record 14 of Set 2 | provideniya
# Processing Record 15 of Set 2 | soe
# Processing Record 16 of Set 2 | emmaus
# Processing Record 17 of Set 2 | new norfolk
# Processing Record 18 of Set 2 | saldanha
# Processing Record 19 of Set 2 | touros
# Processing Record 20 of Set 2 | namibe
# Processing Record 21 of Set 2 | tasiilaq
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | lagoa
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | grand gaube
# Processing Record 26 of Set 2 | turukhansk
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | taksimo
# Processing Record 29 of Set 2 | vanavara
# Processing Record 30 of Set 2 | bambous virieux
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | cidreira
# Processing Record 33 of Set 2 | mar del plata
# Processing Record 34 of Set 2 | tuktoyaktuk
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | akureyri
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | verkhnyaya inta
# Processing Record 40 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 2 | aykhal
# Processing Record 42 of Set 2 | makakilo city
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | erenhot
# Processing Record 45 of Set 2 | port lincoln
# Processing Record 46 of Set 2 | jamestown
# Processing Record 47 of Set 2 | arraial do cabo
# Processing Record 48 of Set 2 | dongsheng
# Processing Record 49 of Set 2 | puri
# Processing Record 50 of Set 2 | kalabo
# Processing Record 1 of Set 3 | lagos
# Processing Record 2 of Set 3 | saint george
# Processing Record 3 of Set 3 | jizan
# Processing Record 4 of Set 3 | ribeira grande
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 3 | boffa
# Processing Record 9 of Set 3 | duz
# City not found. Skipping...
# Processing Record 10 of Set 3 | entebbe
# Processing Record 11 of Set 3 | hithadhoo
# Processing Record 12 of Set 3 | tuatapere
# Processing Record 13 of Set 3 | silva jardim
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | khatanga
# Processing Record 16 of Set 3 | cape town
# Processing Record 17 of Set 3 | pevek
# Processing Record 18 of Set 3 | cayenne
# Processing Record 19 of Set 3 | neiafu
# Processing Record 20 of Set 3 | bredasdorp
# Processing Record 21 of Set 3 | moi
# Processing Record 22 of Set 3 | fortuna
# Processing Record 23 of Set 3 | yingcheng
# Processing Record 24 of Set 3 | banjar
# Processing Record 25 of Set 3 | saskylakh
# Processing Record 26 of Set 3 | maniitsoq
# Processing Record 27 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | saint anthony
# Processing Record 30 of Set 3 | san ignacio
# Processing Record 31 of Set 3 | jinxiang
# Processing Record 32 of Set 3 | novoagansk
# Processing Record 33 of Set 3 | chifeng
# Processing Record 34 of Set 3 | bathsheba
# Processing Record 35 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 36 of Set 3 | puerto ayora
# Processing Record 37 of Set 3 | evensk
# Processing Record 38 of Set 3 | margate
# Processing Record 39 of Set 3 | lebu
# Processing Record 40 of Set 3 | azogues
# Processing Record 41 of Set 3 | karoi
# Processing Record 42 of Set 3 | jiancheng
# Processing Record 43 of Set 3 | deputatskiy
# Processing Record 44 of Set 3 | buala
# Processing Record 45 of Set 3 | vaini
# Processing Record 46 of Set 3 | poum
# Processing Record 47 of Set 3 | mariental
# Processing Record 48 of Set 3 | cabo san lucas
# Processing Record 49 of Set 3 | victoria
# Processing Record 50 of Set 3 | gemena
# Processing Record 1 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 4 | comodoro rivadavia
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | hamilton
# Processing Record 5 of Set 4 | narsaq
# Processing Record 6 of Set 4 | najran
# Processing Record 7 of Set 4 | newport
# Processing Record 8 of Set 4 | shiyan
# Processing Record 9 of Set 4 | padang
# Processing Record 10 of Set 4 | hobart
# Processing Record 11 of Set 4 | bedford
# Processing Record 12 of Set 4 | port-gentil
# Processing Record 13 of Set 4 | tura
# Processing Record 14 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 4 | kavieng
# Processing Record 16 of Set 4 | mantsala
# Processing Record 17 of Set 4 | geraldton
# Processing Record 18 of Set 4 | la ronge
# Processing Record 19 of Set 4 | praia da vitoria
# Processing Record 20 of Set 4 | mount gambier
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | palasbari
# Processing Record 23 of Set 4 | zhezkazgan
# Processing Record 24 of Set 4 | bacolod
# Processing Record 25 of Set 4 | san cristobal
# Processing Record 26 of Set 4 | husavik
# Processing Record 27 of Set 4 | yerkoy
# Processing Record 28 of Set 4 | rundu
# Processing Record 29 of Set 4 | carapur
# Processing Record 30 of Set 4 | bengkulu
# Processing Record 31 of Set 4 | sapa
# Processing Record 32 of Set 4 | monrovia
# Processing Record 33 of Set 4 | bijapur
# Processing Record 34 of Set 4 | churapcha
# Processing Record 35 of Set 4 | sibolga
# Processing Record 36 of Set 4 | olot
# Processing Record 37 of Set 4 | doha
# Processing Record 38 of Set 4 | aparecida do taboado
# Processing Record 39 of Set 4 | leshukonskoye
# Processing Record 40 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 4 | menomonie
# Processing Record 42 of Set 4 | palmer
# Processing Record 43 of Set 4 | vestmannaeyjar
# Processing Record 44 of Set 4 | sangmelima
# Processing Record 45 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 46 of Set 4 | amapa
# Processing Record 47 of Set 4 | karratha
# Processing Record 48 of Set 4 | disna
# Processing Record 49 of Set 4 | mitsamiouli
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 5 | banda aceh
# Processing Record 4 of Set 5 | teplodar
# Processing Record 5 of Set 5 | komsomolskiy
# Processing Record 6 of Set 5 | saint-pierre
# Processing Record 7 of Set 5 | luderitz
# Processing Record 8 of Set 5 | pavino
# Processing Record 9 of Set 5 | grindavik
# Processing Record 10 of Set 5 | urambo
# Processing Record 11 of Set 5 | bubaque
# Processing Record 12 of Set 5 | kaitangata
# Processing Record 13 of Set 5 | moyo
# Processing Record 14 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 15 of Set 5 | faanui
# Processing Record 16 of Set 5 | shu
# Processing Record 17 of Set 5 | jackson
# Processing Record 18 of Set 5 | hilo
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 21 of Set 5 | zhicheng
# Processing Record 22 of Set 5 | klamath falls
# Processing Record 23 of Set 5 | neman
# Processing Record 24 of Set 5 | tambacounda
# Processing Record 25 of Set 5 | richards bay
# Processing Record 26 of Set 5 | andra
# Processing Record 27 of Set 5 | berlevag
# Processing Record 28 of Set 5 | mendi
# Processing Record 29 of Set 5 | atikokan
# Processing Record 30 of Set 5 | congonhas
# Processing Record 31 of Set 5 | esperance
# Processing Record 32 of Set 5 | haines junction
# Processing Record 33 of Set 5 | ilulissat
# Processing Record 34 of Set 5 | tlanepantla
# Processing Record 35 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 36 of Set 5 | santa maria
# Processing Record 37 of Set 5 | cubarral
# Processing Record 38 of Set 5 | gravdal
# Processing Record 39 of Set 5 | koutiala
# Processing Record 40 of Set 5 | kloulklubed
# Processing Record 41 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 5 | aksu
# Processing Record 43 of Set 5 | saint-louis
# Processing Record 44 of Set 5 | guanare
# Processing Record 45 of Set 5 | nanortalik
# Processing Record 46 of Set 5 | jardim
# Processing Record 47 of Set 5 | gigmoto
# Processing Record 48 of Set 5 | burnie
# Processing Record 49 of Set 5 | yulara
# Processing Record 50 of Set 5 | allahabad
# Processing Record 1 of Set 6 | aba
# Processing Record 2 of Set 6 | praya
# Processing Record 3 of Set 6 | alamogordo
# Processing Record 4 of Set 6 | spetsai
# City not found. Skipping...
# Processing Record 5 of Set 6 | abha
# Processing Record 6 of Set 6 | tarhunah
# City not found. Skipping...
# Processing Record 7 of Set 6 | coihaique
# Processing Record 8 of Set 6 | talnakh
# Processing Record 9 of Set 6 | lamar
# Processing Record 10 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 11 of Set 6 | westport
# Processing Record 12 of Set 6 | alghero
# Processing Record 13 of Set 6 | currais novos
# Processing Record 14 of Set 6 | ancud
# Processing Record 15 of Set 6 | standerton
# Processing Record 16 of Set 6 | carnarvon
# Processing Record 17 of Set 6 | salalah
# Processing Record 18 of Set 6 | tigre
# Processing Record 19 of Set 6 | kerteh
# City not found. Skipping...
# Processing Record 20 of Set 6 | santiago del estero
# Processing Record 21 of Set 6 | upernavik
# Processing Record 22 of Set 6 | sao joao da barra
# Processing Record 23 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 24 of Set 6 | razdolnoye
# Processing Record 25 of Set 6 | aksarka
# Processing Record 26 of Set 6 | oranjemund
# Processing Record 27 of Set 6 | baykit
# Processing Record 28 of Set 6 | tiarei
# Processing Record 29 of Set 6 | varhaug
# Processing Record 30 of Set 6 | rio grande
# Processing Record 31 of Set 6 | vila velha
# Processing Record 32 of Set 6 | chihuahua
# Processing Record 33 of Set 6 | itoman
# Processing Record 34 of Set 6 | iqaluit
# Processing Record 35 of Set 6 | bolshaya glushitsa
# Processing Record 36 of Set 6 | ponta delgada
# Processing Record 37 of Set 6 | austin
# Processing Record 38 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 39 of Set 6 | motala
# Processing Record 40 of Set 6 | nelson bay
# Processing Record 41 of Set 6 | evansville
# Processing Record 42 of Set 6 | palmeirais
# Processing Record 43 of Set 6 | vostok
# Processing Record 44 of Set 6 | iquique
# Processing Record 45 of Set 6 | zhatay
# Processing Record 46 of Set 6 | ambulu
# Processing Record 47 of Set 6 | san quintin
# Processing Record 48 of Set 6 | lac-megantic
# Processing Record 49 of Set 6 | tessalit
# Processing Record 50 of Set 6 | olafsvik
# Processing Record 1 of Set 7 | katobu
# Processing Record 2 of Set 7 | arman
# Processing Record 3 of Set 7 | brae
# Processing Record 4 of Set 7 | channel-port aux basques
# Processing Record 5 of Set 7 | togur
# Processing Record 6 of Set 7 | mizan teferi
# Processing Record 7 of Set 7 | chuy
# Processing Record 8 of Set 7 | marsh harbour
# Processing Record 9 of Set 7 | fare
# Processing Record 10 of Set 7 | pangnirtung
# Processing Record 11 of Set 7 | methoni
# Processing Record 12 of Set 7 | nishihara
# Processing Record 13 of Set 7 | dicabisagan
# Processing Record 14 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 15 of Set 7 | praia
# Processing Record 16 of Set 7 | lubao
# Processing Record 17 of Set 7 | damietta
# Processing Record 18 of Set 7 | marsabit
# Processing Record 19 of Set 7 | isangel
# Processing Record 20 of Set 7 | byron bay
# Processing Record 21 of Set 7 | nyurba
# Processing Record 22 of Set 7 | namatanai
# Processing Record 23 of Set 7 | imbituba
# Processing Record 24 of Set 7 | maumere
# Processing Record 25 of Set 7 | sorland
# Processing Record 26 of Set 7 | lima
# Processing Record 27 of Set 7 | higuey
# City not found. Skipping...
# Processing Record 28 of Set 7 | marrakesh
# Processing Record 29 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 7 | batemans bay
# Processing Record 31 of Set 7 | jaguarari
# Processing Record 32 of Set 7 | lorengau
# Processing Record 33 of Set 7 | yeppoon
# Processing Record 34 of Set 7 | chadiza
# Processing Record 35 of Set 7 | bristol
# Processing Record 36 of Set 7 | mahon
# Processing Record 37 of Set 7 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 7 | sechura
# Processing Record 39 of Set 7 | ferrol
# Processing Record 40 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 7 | campobasso
# Processing Record 42 of Set 7 | kincardine
# Processing Record 43 of Set 7 | denpasar
# Processing Record 44 of Set 7 | mandalay
# Processing Record 45 of Set 7 | inzer
# Processing Record 46 of Set 7 | agua verde
# Processing Record 47 of Set 7 | acari
# Processing Record 48 of Set 7 | dwarka
# Processing Record 49 of Set 7 | abu kamal
# Processing Record 50 of Set 7 | qasigiannguit
# Processing Record 1 of Set 8 | bembereke
# Processing Record 2 of Set 8 | sao filipe
# Processing Record 3 of Set 8 | maykain
# City not found. Skipping...
# Processing Record 4 of Set 8 | katsuura
# Processing Record 5 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 6 of Set 8 | bulgan
# Processing Record 7 of Set 8 | labuhan
# Processing Record 8 of Set 8 | mandalgovi
# Processing Record 9 of Set 8 | progreso
# Processing Record 10 of Set 8 | kamuli
# Processing Record 11 of Set 8 | yar-sale
# Processing Record 12 of Set 8 | fairbanks
# Processing Record 13 of Set 8 | kruisfontein
# Processing Record 14 of Set 8 | mbandaka
# Processing Record 15 of Set 8 | birao
# Processing Record 16 of Set 8 | muniz freire
# Processing Record 17 of Set 8 | khorixas
# Processing Record 18 of Set 8 | launceston
# Processing Record 19 of Set 8 | synya
# Processing Record 20 of Set 8 | arlit
# Processing Record 21 of Set 8 | te anau
# Processing Record 22 of Set 8 | tevriz
# Processing Record 23 of Set 8 | timmins
# Processing Record 24 of Set 8 | along
# Processing Record 25 of Set 8 | porbandar
# Processing Record 26 of Set 8 | hovd
# Processing Record 27 of Set 8 | faya
# Processing Record 28 of Set 8 | beringovskiy
# Processing Record 29 of Set 8 | qinhuangdao
# Processing Record 30 of Set 8 | sabha
# Processing Record 31 of Set 8 | marzuq
# Processing Record 32 of Set 8 | zyryanka
# Processing Record 33 of Set 8 | hamamatsu
# Processing Record 34 of Set 8 | inuvik
# Processing Record 35 of Set 8 | shimoda
# Processing Record 36 of Set 8 | hatillo
# Processing Record 37 of Set 8 | parrita
# Processing Record 38 of Set 8 | walvis bay
# Processing Record 39 of Set 8 | paita
# Processing Record 40 of Set 8 | torres
# Processing Record 41 of Set 8 | bien hoa
# Processing Record 42 of Set 8 | pemangkat
# Processing Record 43 of Set 8 | chapais
# Processing Record 44 of Set 8 | college
# Processing Record 45 of Set 8 | missoula
# Processing Record 46 of Set 8 | paragominas
# Processing Record 47 of Set 8 | chimbote
# Processing Record 48 of Set 8 | iranshahr
# Processing Record 49 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 8 | uzumlu
# City not found. Skipping...
# Processing Record 1 of Set 9 | umm kaddadah
# Processing Record 2 of Set 9 | biltine
# Processing Record 3 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 4 of Set 9 | kongwa
# Processing Record 5 of Set 9 | chinsali
# Processing Record 6 of Set 9 | sao pedro do sul
# Processing Record 7 of Set 9 | manosque
# Processing Record 8 of Set 9 | klaksvik
# Processing Record 9 of Set 9 | providencia
# Processing Record 10 of Set 9 | fort nelson
# Processing Record 11 of Set 9 | papasquiaro
# City not found. Skipping...
# Processing Record 12 of Set 9 | aquiraz
# Processing Record 13 of Set 9 | san pedro del parana
# Processing Record 14 of Set 9 | oktyabrskiy
# Processing Record 15 of Set 9 | raurkela
# City not found. Skipping...
# Processing Record 16 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 17 of Set 9 | zinacantan
# Processing Record 18 of Set 9 | tanout
# Processing Record 19 of Set 9 | santa rosa
# Processing Record 20 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 9 | hobyo
# Processing Record 22 of Set 9 | dunedin
# Processing Record 23 of Set 9 | pavlodar
# Processing Record 24 of Set 9 | alice springs
# Processing Record 25 of Set 9 | winslow
# Processing Record 26 of Set 9 | orsha
# Processing Record 27 of Set 9 | santa maria da vitoria
# Processing Record 28 of Set 9 | atocha
# Processing Record 29 of Set 9 | berdigestyakh
# Processing Record 30 of Set 9 | hualmay
# Processing Record 31 of Set 9 | lumeje
# Processing Record 32 of Set 9 | australind
# Processing Record 33 of Set 9 | sidney
# Processing Record 34 of Set 9 | manta
# Processing Record 35 of Set 9 | thompson
# Processing Record 36 of Set 9 | asau
# Processing Record 37 of Set 9 | rehoboth
# Processing Record 38 of Set 9 | taoudenni
# Processing Record 39 of Set 9 | norman wells
# Processing Record 40 of Set 9 | flin flon
# Processing Record 41 of Set 9 | ust-nera
# Processing Record 42 of Set 9 | aswan
# Processing Record 43 of Set 9 | krasnoselkup
# Processing Record 44 of Set 9 | voyinka
# Processing Record 45 of Set 9 | lashio
# Processing Record 46 of Set 9 | sao lourenco da serra
# Processing Record 47 of Set 9 | meiganga
# Processing Record 48 of Set 9 | dudinka
# Processing Record 49 of Set 9 | novo aripuana
# Processing Record 50 of Set 9 | kargil
# Processing Record 1 of Set 10 | hay river
# Processing Record 2 of Set 10 | gore
# Processing Record 3 of Set 10 | belmonte
# Processing Record 4 of Set 10 | srednekolymsk
# Processing Record 5 of Set 10 | columbus
# Processing Record 6 of Set 10 | penzance
# Processing Record 7 of Set 10 | general roca
# Processing Record 8 of Set 10 | acapulco
# Processing Record 9 of Set 10 | berea
# Processing Record 10 of Set 10 | kysyl-syr
# Processing Record 11 of Set 10 | kalmunai
# Processing Record 12 of Set 10 | saint-philippe
# Processing Record 13 of Set 10 | codajas
# Processing Record 14 of Set 10 | quelimane
# Processing Record 15 of Set 10 | minot
# Processing Record 16 of Set 10 | mora
# Processing Record 17 of Set 10 | great yarmouth
# Processing Record 18 of Set 10 | aripuana
# Processing Record 19 of Set 10 | nemuro
# Processing Record 20 of Set 10 | alcaniz
# Processing Record 21 of Set 10 | alofi
# Processing Record 22 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 24 of Set 10 | abu dhabi
# Processing Record 25 of Set 10 | cape canaveral
# Processing Record 26 of Set 10 | santa cruz cabralia
# Processing Record 27 of Set 10 | nioro
# Processing Record 28 of Set 10 | arrifes
# Processing Record 29 of Set 10 | nome
# Processing Record 30 of Set 10 | kirakira
# Processing Record 31 of Set 10 | kahului
# Processing Record 32 of Set 10 | sitka
# Processing Record 33 of Set 10 | mount isa
# Processing Record 34 of Set 10 | souillac
# Processing Record 35 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 10 | rondonopolis
# Processing Record 37 of Set 10 | calvinia
# Processing Record 38 of Set 10 | havelock
# Processing Record 39 of Set 10 | west linton
# Processing Record 40 of Set 10 | canton
# Processing Record 41 of Set 10 | kozhva
# Processing Record 42 of Set 10 | tomatlan
# Processing Record 43 of Set 10 | zwettl
# Processing Record 44 of Set 10 | laguna
# Processing Record 45 of Set 10 | limbe
# Processing Record 46 of Set 10 | bentiu
# Processing Record 47 of Set 10 | tambun
# Processing Record 48 of Set 10 | monte alegre
# Processing Record 49 of Set 10 | egvekinot
# Processing Record 50 of Set 10 | chara
# Processing Record 1 of Set 11 | auki
# Processing Record 2 of Set 11 | marawi
# Processing Record 3 of Set 11 | varca
# Processing Record 4 of Set 11 | warrnambool
# Processing Record 5 of Set 11 | ouegoa
# Processing Record 6 of Set 11 | ambilobe
# Processing Record 7 of Set 11 | cooma
# Processing Record 8 of Set 11 | cap-aux-meules
# Processing Record 9 of Set 11 | okhotsk
# Processing Record 10 of Set 11 | aras
# Processing Record 11 of Set 11 | pushkinskiye gory
# Processing Record 12 of Set 11 | paralimni
# Processing Record 13 of Set 11 | koslan
# Processing Record 14 of Set 11 | inhambane
# Processing Record 15 of Set 11 | freetown
# Processing Record 16 of Set 11 | ihosy
# Processing Record 17 of Set 11 | abu samrah
# Processing Record 18 of Set 11 | xining
# Processing Record 19 of Set 11 | porto novo
# Processing Record 20 of Set 11 | buchanan
# Processing Record 21 of Set 11 | margherita
# Processing Record 22 of Set 11 | carutapera
# Processing Record 23 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 11 | tangjiazhuang
# Processing Record 25 of Set 11 | wagar
# Processing Record 26 of Set 11 | hellin
# Processing Record 27 of Set 11 | ballina
# Processing Record 28 of Set 11 | rosario do sul
# Processing Record 29 of Set 11 | tombouctou
# Processing Record 30 of Set 11 | san juan
# Processing Record 31 of Set 11 | kedrovyy
# Processing Record 32 of Set 11 | lata
# Processing Record 33 of Set 11 | helong
# Processing Record 34 of Set 11 | kingaroy
# Processing Record 35 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 36 of Set 11 | matara
# Processing Record 37 of Set 11 | hami
# Processing Record 38 of Set 11 | chutung
# City not found. Skipping...
# Processing Record 39 of Set 11 | kabelvag
# Processing Record 40 of Set 11 | vao
# Processing Record 41 of Set 11 | marsa matruh
# Processing Record 42 of Set 11 | nago
# Processing Record 43 of Set 11 | taga
# Processing Record 44 of Set 11 | tateyama
# Processing Record 45 of Set 11 | vestmanna
# Processing Record 46 of Set 11 | sinnamary
# Processing Record 47 of Set 11 | ghanzi
# Processing Record 48 of Set 11 | wanderlandia
# City not found. Skipping...
# Processing Record 49 of Set 11 | coahuayana
# Processing Record 50 of Set 11 | otacilio costa
# Processing Record 1 of Set 12 | coachella
# Processing Record 2 of Set 12 | cabedelo
# Processing Record 3 of Set 12 | beboto
# Processing Record 4 of Set 12 | sola
# Processing Record 5 of Set 12 | porto tolle
# Processing Record 6 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 12 | kinsale
# Processing Record 8 of Set 12 | hervey bay
# Processing Record 9 of Set 12 | lasa
# Processing Record 10 of Set 12 | bundaberg
# Processing Record 11 of Set 12 | yarmouth
# Processing Record 12 of Set 12 | dvinskoy
# Processing Record 13 of Set 12 | baghdad
# Processing Record 14 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 12 | muhos
# Processing Record 16 of Set 12 | tevaitoa
# Processing Record 17 of Set 12 | beckley
# Processing Record 18 of Set 12 | kabinda
# Processing Record 19 of Set 12 | henties bay
# Processing Record 20 of Set 12 | ferkessedougou
# Processing Record 21 of Set 12 | port keats
# Processing Record 22 of Set 12 | ghaziabad
# Processing Record 23 of Set 12 | matay
# Processing Record 24 of Set 12 | santa cruz de tenerife
# Processing Record 25 of Set 12 | verkhnyaya toyma
# Processing Record 26 of Set 12 | ostrovnoy
# Processing Record 27 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 12 | bambanglipuro
# Processing Record 29 of Set 12 | leeton
# Processing Record 30 of Set 12 | kaohsiung
# Processing Record 31 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 32 of Set 12 | hambantota
# Processing Record 33 of Set 12 | mahibadhoo
# Processing Record 34 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 35 of Set 12 | mangochi
# Processing Record 36 of Set 12 | ahwa
# Processing Record 37 of Set 12 | mangan
# Processing Record 38 of Set 12 | concepcion del oro
# Processing Record 39 of Set 12 | maceio
# Processing Record 40 of Set 12 | bandarbeyla
# Processing Record 41 of Set 12 | ushirombo
# Processing Record 42 of Set 12 | chenghai
# Processing Record 43 of Set 12 | kintampo
# Processing Record 44 of Set 12 | ayan
# Processing Record 45 of Set 12 | riyadh
# Processing Record 46 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 47 of Set 12 | sao felix do xingu
# Processing Record 48 of Set 12 | luorong
# Processing Record 49 of Set 12 | bijie
# Processing Record 50 of Set 12 | richard toll
# City not found. Skipping...
# Processing Record 1 of Set 13 | vanimo
# Processing Record 2 of Set 13 | tilichiki
# Processing Record 3 of Set 13 | dakar
# Processing Record 4 of Set 13 | tiznit
# Processing Record 5 of Set 13 | kaeo
# Processing Record 6 of Set 13 | kaliyaganj
# Processing Record 7 of Set 13 | jumla
# Processing Record 8 of Set 13 | rabo de peixe
# Processing Record 9 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 10 of Set 13 | teguldet
# Processing Record 11 of Set 13 | manokwari
# Processing Record 12 of Set 13 | tromso
# Processing Record 13 of Set 13 | gandu
# Processing Record 14 of Set 13 | lavrentiya
# Processing Record 15 of Set 13 | terrace
# Processing Record 16 of Set 13 | la paz
# Processing Record 17 of Set 13 | tsabong
# Processing Record 18 of Set 13 | katherine
# Processing Record 19 of Set 13 | rovaniemi
# Processing Record 20 of Set 13 | flinders
# Processing Record 21 of Set 13 | port lavaca
# Processing Record 22 of Set 13 | tahe
# Processing Record 23 of Set 13 | vila franca do campo
# Processing Record 24 of Set 13 | jawhar
# Processing Record 25 of Set 13 | winneba
# Processing Record 26 of Set 13 | bogorodskoye
# Processing Record 27 of Set 13 | arkhangelsk
# Processing Record 28 of Set 13 | cap malheureux
# Processing Record 29 of Set 13 | aasiaat
# Processing Record 30 of Set 13 | solnechnyy
# Processing Record 31 of Set 13 | mahajanga
# Processing Record 32 of Set 13 | barstow
# Processing Record 33 of Set 13 | alexandria
# Processing Record 34 of Set 13 | kefamenanu
# Processing Record 35 of Set 13 | wanning
# Processing Record 36 of Set 13 | tual
# Processing Record 37 of Set 13 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 13 | bilma
# Processing Record 39 of Set 13 | ganzhou
# Processing Record 40 of Set 13 | san patricio
# Processing Record 41 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | bury saint edmunds
# City not found. Skipping...
# Processing Record 43 of Set 13 | imisli
# City not found. Skipping...
# Processing Record 44 of Set 13 | wawa
# Processing Record 45 of Set 13 | kudahuvadhoo
# Processing Record 46 of Set 13 | semnan
# Processing Record 47 of Set 13 | kaniama
# Processing Record 48 of Set 13 | romilly-sur-seine
# Processing Record 49 of Set 13 | batagay-alyta
# Processing Record 50 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 14 | phan thiet
# Processing Record 2 of Set 14 | santa paula
# Processing Record 3 of Set 14 | christchurch
# Processing Record 4 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 14 | misratah
# Processing Record 6 of Set 14 | gao
# Processing Record 7 of Set 14 | maningrida
# Processing Record 8 of Set 14 | san javier
# Processing Record 9 of Set 14 | aldergrove
# Processing Record 10 of Set 14 | staroutkinsk
# Processing Record 11 of Set 14 | kontagora
# Processing Record 12 of Set 14 | kanigoro
# Processing Record 13 of Set 14 | george
# Processing Record 14 of Set 14 | mackay
# Processing Record 15 of Set 14 | puerto escondido
# Processing Record 16 of Set 14 | malm
# Processing Record 17 of Set 14 | dargaville
# Processing Record 18 of Set 14 | chumikan
# Processing Record 19 of Set 14 | vinces
# Processing Record 20 of Set 14 | am timan
# Processing Record 21 of Set 14 | khasan
# Processing Record 22 of Set 14 | mana
# Processing Record 23 of Set 14 | ozernovskiy
# Processing Record 24 of Set 14 | portland
# Processing Record 25 of Set 14 | wahiawa
# Processing Record 26 of Set 14 | cordoba
# Processing Record 27 of Set 14 | great falls
# Processing Record 28 of Set 14 | necochea
# Processing Record 29 of Set 14 | tezu
# Processing Record 30 of Set 14 | hofn
# Processing Record 31 of Set 14 | pandan
# Processing Record 32 of Set 14 | porto nacional
# Processing Record 33 of Set 14 | quchan
# Processing Record 34 of Set 14 | phalombe
# Processing Record 35 of Set 14 | port hedland
# Processing Record 36 of Set 14 | nagato
# Processing Record 37 of Set 14 | juquia
# Processing Record 38 of Set 14 | healdsburg
# Processing Record 39 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 40 of Set 14 | sao joaquim
# Processing Record 41 of Set 14 | charlestown
# Processing Record 42 of Set 14 | seredka
# Processing Record 43 of Set 14 | mocuba
# Processing Record 44 of Set 14 | ruteng
# Processing Record 45 of Set 14 | agen
# Processing Record 46 of Set 14 | stavern
# Processing Record 47 of Set 14 | monroe
# Processing Record 48 of Set 14 | umm lajj
# Processing Record 49 of Set 14 | nizhnevartovsk
# Processing Record 50 of Set 14 | alto araguaia
# Processing Record 1 of Set 15 | opuwo
# Processing Record 2 of Set 15 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 3 of Set 15 | epe
# Processing Record 4 of Set 15 | goderich
# Processing Record 5 of Set 15 | aguimes
# Processing Record 6 of Set 15 | kholodnyy
# Processing Record 7 of Set 15 | xai-xai
# Processing Record 8 of Set 15 | prince rupert
# Processing Record 9 of Set 15 | kavaratti
# Processing Record 10 of Set 15 | izmir
# Processing Record 11 of Set 15 | wewak
# Processing Record 12 of Set 15 | ust-shonosha
# Processing Record 13 of Set 15 | stawell
# Processing Record 14 of Set 15 | zhigansk
# Processing Record 15 of Set 15 | caronport
# Processing Record 16 of Set 15 | havre-saint-pierre
# Processing Record 17 of Set 15 | los llanos de aridane
# Processing Record 18 of Set 15 | port augusta
# Processing Record 19 of Set 15 | tosya
# Processing Record 20 of Set 15 | telford
# Processing Record 21 of Set 15 | maturin
# Processing Record 22 of Set 15 | ahipara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Barrow      US  71.29 -156.79     42.80        81          90
# 1       Ushuaia      AR -54.80  -68.30     39.20        93          90
# 2        Castro      BR -24.79  -50.01     52.00        96         100
# 3        Avarua      CK -21.21 -159.78     75.20        78         100
# 4     Mahebourg      MU -20.41   57.70     68.00        82          75
# 5     Busselton      AU -33.65  115.33     51.01        82          78
# 6  Constitucion      CL -35.33  -72.42     47.89        71           0
# 7     Ulladulla      AU -35.35  150.47     55.99        50          20
# 8     Iskateley      RU  67.68   53.15     49.78        97          83
# 9  Punta Arenas      CL -53.15  -70.92     44.60        75          83
#
#    Wind Speed Current Description
# 0       10.29     overcast clouds
# 1       24.16     overcast clouds
# 2        2.15          light rain
# 3       20.80     overcast clouds
# 4       11.41         shower rain
# 5        1.21          light rain
# 6        6.71           clear sky
# 7       27.51          few clouds
# 8       11.12       broken clouds
# 9       26.40       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
